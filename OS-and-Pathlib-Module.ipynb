# %% [markdown]
# OS MODULE:
# It contains 2 modules:
# 1. os module
# 2. os.path module

# %%
import os
print(os.getcwd())
print(os.getcwdb())
# Out:
# d:\XenoDev09\Python
# b'd:\\XenoDev09\\Python'

# %%
import os
#os.chdir('/home/....') changing cwd
#os.mkdir()
#os.makedirs()
#os.path.join(parent_dir,directory)
print(os.listdir(".")) #current directory
print(os.listdir("..")) #parent directory
print(os.walk("..")) #parent directory
#os.remove() To remove path
#os.rmdir() To remove dir with no files
#shutil.rmtree(path) To remove dir and its contained files
#os.path.getatime(path) returns timestand when the dir is accessed
#os.path.getmtime(path) returns timestand when the dir is modified
# Out:
# ['.git', 'asyncProgramming.py', 'Basics.ipynb', 'Data-Types.ipynb', 'File-Handling.ipynb', 'HelloWorld.py', 'Oop.ipynb', 'OS-and-Pathlib-Module.ipynb', 'Python-Exception-Handling.ipynb', 'README.md', 'sample.txt', 'Test.csv', 'Test.json', 'test.txt']
# ['ALLAUTH-Django', 'DEMO', 'Flutter', 'KCT-Dotnet', 'NumPy', 'php', 'Python', 'react_learning', 'rest_framework_django', 'Role_based_login_system', 'Website-Templates']
# <generator object walk at 0x000002528EB4C600>

# %% [markdown]
# COMMONLY USED FUNCTIONS:

# %%
import os 
print(os.name)
print(os.error) # Alias OSError for error handling
# Out:
# nt
# <class 'OSError'>

# %%
import os

output = os.popen("dir")   # Windows
print(output.read())
# Out:
#  Volume in drive D is NO-ENTRY
#  Volume Serial Number is 30C7-665B
#
#  Directory of d:\XenoDev09\Python
#
# 01/20/2026  09:13 PM    <DIR>          .
# 01/15/2026  03:13 PM    <DIR>          ..
# 01/15/2026  12:12 PM               125 asyncProgramming.py
# 01/15/2026  12:40 PM            15,931 Basics.ipynb
# 01/15/2026  01:56 PM             4,955 Data-Types.ipynb
# 01/20/2026  09:12 PM             9,054 File-Handling.ipynb
# 01/15/2026  12:14 PM                28 HelloWorld.py
# 01/18/2026  03:56 PM            11,826 Oop.ipynb
# 01/20/2026  09:46 PM             3,101 OS-and-Pathlib-Module.ipynb
# 01/20/2026  08:34 PM             5,878 Python-Exception-Handling.ipynb
# 01/15/2026  10:03 AM                43 README.md
# 01/20/2026  08:45 PM               248 sample.txt
# 01/20/2026  09:02 PM               749 Test.csv
# 01/20/2026  09:03 PM             1,967 Test.json
# 01/20/2026  09:12 PM                65 test.txt
#               13 File(s)         53,970 bytes
# ...

# %% [markdown]
# PATHLIB MODULE:
# Path class in pathlin is divided into two:
# 1. pure path -used for computational operations not for IO operations
# 2. concrete path -Inherited from pure path used for noth computational and IO operations
